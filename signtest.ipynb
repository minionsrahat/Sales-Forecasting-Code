# %%
# Wilcoxon signed-rank test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import wilcoxon
import numpy as np
from scipy.stats import stats
# seed the random number generator
seed(1)
# generate two independent samples
data1 = 5 * randn(100) + 50
data2 = 5 * randn(100) + 51
data=np.array([14.72,25.44, 24.56 ,15.55])
x=[14.72/100]
q=np.array([7.43/100])
# compare samples
stat, p = wilcoxon(x-q)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=0.000, p=0.317
# Same distribution (fail to reject H0)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:2879: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %%
x-q
# Out:
# array([0.0729])

# %%
n=q-x

# %%
n
# Out:
# array([-0.0729])

# %%
stat, p = wilcoxon(n)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=0.000, p=0.317
# Same distribution (fail to reject H0)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:2879: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/Signtest2.csv")

#convert date field from string to datetime
#df['date'] = pd.to_datetime(df['date'])Machine_learning_FORECAST_Updates

# %%
df=df*100

# %%
df.head()
# Out:
#      ANN   CNN   DNN   LSTM    RNN  CNN+LSTM  Stacked
# 0    9.0  46.0  25.0    9.0   33.0      13.0     11.0
# 1   39.0  39.0  23.0   37.0   25.0      34.0     15.0
# 2   38.0  16.0  19.0   40.0   17.0      46.0     11.0
# 3  175.0  81.0  88.0  163.0  198.0     211.0     56.0
# 4    0.0  14.0   3.0    1.0   13.0      12.0      1.0

# %%
stat, p,z = wilcoxon(df['Stacked'],df['LSTM'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
print(p)
print(z)

# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=15.500, p=0.000
# 1.4180502377137513e-06
# -4.82245078601792
# Different distribution (reject H0)

# %%
wilcoxon(df['Stacked']-df['CNN+LSTM'])
# Out:
# (9.0, 7.011606525270715e-08, -5.390873386597615)

# %%
e1=(df['actual_value']-df['ANN'])-(df['actual_value']-df['ANN'])

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         Date  Actual Value        ANN        CNN        DNN       LSTM  \
# 0   19-09-13        14.310  13.057549   7.776599  10.766014  13.019789
# 1   20-09-13        20.102  12.218282  12.236856  15.577593  12.660336
# 2   21-09-13        20.500  12.707234  17.255718  16.694240  12.287121
# 3   22-09-13         4.624  12.704515   8.369113   8.675044  12.171265
# 4   23-09-13        13.773  13.832393  11.844850  14.132401  13.567509
# 5   24-09-13        11.822  12.100300   9.005859  12.103533  12.933136
# 6   25-09-13        15.561  12.669759  13.616255  15.005844  12.892848
# 7   26-09-13        11.520  12.539581  13.162771  14.085648  12.564834
# 8   27-09-13        16.106  12.746404  15.145874  14.357890  12.756491
# 9   28-09-13        14.261  12.679556  12.106447  16.284695  12.459688
# 10  29-09-13         9.749  12.205697  10.487706   8.918785  12.469789
# 11  30-09-13        28.771  13.183820  12.613724  16.321781  12.902828
# ...

# %%
e1.dropna(inplace=True)

# %%
stat, p = wilcoxon(e1)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# Out:
# Statistics=298.000, p=0.132

# %%
e1=np.abs(e1)

# %%
# Out:
#       ANN    CNN    DNN   LSTM    RNN  CNN+LSTM  Stacked
# 0     9.0   46.0   25.0    9.0   33.0      13.0     11.0
# 1    39.0   39.0   23.0   37.0   25.0      34.0     15.0
# 2    38.0   16.0   19.0   40.0   17.0      46.0     11.0
# 3   175.0   81.0   88.0  163.0  198.0     211.0     56.0
# 4     0.0   14.0    3.0    1.0   13.0      12.0      1.0
# 5     2.0   24.0    2.0    9.0   26.0       9.0      2.0
# 6    19.0   12.0    4.0   17.0    8.0      21.0      2.0
# 7     9.0   14.0   22.0    9.0    6.0      23.0      9.0
# 8    21.0    6.0   11.0   21.0    5.0      12.0      2.0
# 9    11.0   15.0   14.0   13.0    6.0      15.0      3.0
# 10   25.0    8.0    9.0   28.0   63.0      22.0      0.0
# 11   54.0   56.0   43.0   55.0   51.0      40.0     28.0
# 12    4.0    6.0    3.0    9.0    5.0       4.0      2.0
# 13   34.0   23.0   20.0   33.0   23.0      25.0     13.0
# 14    8.0    9.0    0.0    4.0   15.0      19.0      0.0
# ...

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
np.mean(np.abs((14.310 - 7.788999) / 14.310)) * 100
# Out:
# 45.56953878406709

# %%
mean_absolute_percentage_error(error['true'],error['prophet+cnn'])
# Out:
# 38.591528081126185

# %%
error.head(2)
# Out:
#          date    true    prophet  prophet+dnn  prophet+RNN  prophet+cnn
# 0  2013-09-19  14.310   7.665394     8.998369    10.533403     7.788999
# 1  2013-09-20  20.102  12.386030    13.186590    14.746724    14.028135

# %%
error.apply(lambda x: mean_absolute_percentage_error(x['true'], x['prophet+cnn']), axis=1)
# Out:
# 0      45.569539
# 1      30.215228
# 2      33.596002
# 3      82.351826
# 4      13.757282
# 5      35.514376
# 6       4.430137
# 7       7.694348
# 8      23.849735
# 9       0.296893
# 10     29.512376
# 11     56.339049
# 12      2.675267
# 13     53.864426
# 14     40.573175
# 15     20.646539
# 16      8.778693
# 17     24.064302
# 18      8.891442
# 19     31.987413
# 20     27.382404
# 21      5.094088
# 22     45.136370
# 23    293.244040
# 24    214.447718
# 25     12.168752
# 26     23.732086
# 27     20.240345
# 28      6.254639
# 29     10.283592
# 30     33.938742
# 31     65.232455
# 32     48.265112
# 33     14.567773
# 34     22.598064
# 35     31.154177
# 36     27.459902
# 37      7.949357
# 38     37.990206
# 39     41.913253
# dtype: float64

# %%
= pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/data/Splited Data s-1 to s-5/STEST/S_1__I_582865.csv",parse_dates=['date'],index_col='date')

#convert date field from string to datetime
#df['date'] = pd.to_datetime(df['date'])

# %%
 mean_absolute_percentage_error(12.771,12.4546046666667)
# Out:
# 2.477451517761338

# %%
import scipy
scipy.stats.wilcoxon(df['Stacked'],df['DNN'], correction=True)
# Out:
# WilcoxonResult(statistic=0.0, pvalue=7.9663723324991e-08)

# %%
import numpy as np
import pingouin as pg
pg.wilcoxon(df['Stacked'],df['DNN'], correction=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-149-da73c9d9ded0> in <module>
#       1 import numpy as np
# ----> 2 import pingouin as pg
#       3 pg.wilcoxon(df['Stacked'],df['DNN'], correction=True)
#
# ModuleNotFoundError: No module named 'pingouin'

# %%
from numpy import (asarray, compress) # requiered for local modification
from scipy.stats import (find_repeats, distributions)
from math import sqrt
def wilcoxon(x, y=None, zero_method="wilcox", correction=False):
    """
    Calculate the Wilcoxon signed-rank test.

    The Wilcoxon signed-rank test tests the null hypothesis that two
    related paired samples come from the same distribution. In particular,
    it tests whether the distribution of the differences x - y is symmetric
    about zero. It is a non-parametric version of the paired T-test.

    Parameters
    ----------
    x : array_like
        The first set of measurements.
    y : array_like, optional
        The second set of measurements.  If `y` is not given, then the `x`
        array is considered to be the differences between the two sets of
        measurements.
    zero_method : string, {"pratt", "wilcox", "zsplit"}, optional
        "pratt":
            Pratt treatment: includes zero-differences in the ranking process
            (more conservative)
        "wilcox":
            Wilcox treatment: discards all zero-differences
        "zsplit":
            Zero rank split: just like Pratt, but splitting the zero rank
            between positive and negative ones
    correction : bool, optional
        If True, apply continuity correction by adjusting the Wilcoxon rank
        statistic by 0.5 towards the mean value when computing the
        z-statistic.  Default is False.

    Returns
    -------
    statistic : float
        The sum of the ranks of the differences above or below zero, whichever
        is smaller.
    pvalue : float
        The two-sided p-value for the test.

    Notes
    -----
    Because the normal approximation is used for the calculations, the
    samples used should be large.  A typical rule is to require that
    n > 20.

    References
    ----------
    .. [1] https://en.wikipedia.org/wiki/Wilcoxon_signed-rank_test

    """


    if zero_method not in ["wilcox", "pratt", "zsplit"]:
        raise ValueError("Zero method should be either 'wilcox' "
                         "or 'pratt' or 'zsplit'")


    if y is None:
        d = asarray(x)
    else:
        x, y = map(asarray, (x, y))
        if len(x) != len(y):
            raise ValueError('Unequal N in wilcoxon.  Aborting.')
        d = x - y


    if zero_method == "wilcox":
        # Keep all non-zero differences
        d = compress(np.not_equal(d, 0), d, axis=-1)


    count = len(d)
    if count < 10:
        warnings.warn("Warning: sample size too small for normal approximation.")


    r = stats.rankdata(abs(d))
    r_plus = np.sum((d > 0) * r, axis=0)
    r_minus = np.sum((d < 0) * r, axis=0)


    if zero_method == "zsplit":
        r_zero = np.sum((d == 0) * r, axis=0)
        r_plus += r_zero / 2.
        r_minus += r_zero / 2.


    T = min(r_plus, r_minus)
    mn = count * (count + 1.) * 0.25
    se = count * (count + 1.) * (2. * count + 1.)


    if zero_method == "pratt":
        r = r[d != 0]


    replist, repnum = find_repeats(r)
    if repnum.size != 0:
        # Correction for repeated elements.
        se -= 0.5 * (repnum * (repnum * repnum - 1)).sum()


    se = sqrt(se / 24)
    correction = 0.5 * int(bool(correction)) * np.sign(T - mn)
    z = (T - mn - correction) / se
    prob = 2. * distributions.norm.sf(abs(z))


    return T, prob, z

# %%
signtest= pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/Hybrid_signtest.csv")

# %%
signtest.head()
# Out:
#    ATES + CNN  ATES + DNN  ATES + GRU  ATES + GRU_CNN_LSTM  Actual Value
# 0    8.742965   10.866416   12.067019            14.067650        14.310
# 1   17.883600   15.613717   13.577691            18.450144        20.102
# 2   20.927123   14.565159   15.590494            19.292836        20.500
# 3   14.716010   15.513791   16.485517             2.064633         4.624
# 4   22.604494   15.731198   14.595418            13.847580        13.773

# %%
dff=pd.DataFrame(columns=['ATES + CNN','ATES + DNN','ATES + GRU','ATES + GRU_CNN_LSTM'])

# %%
dff['ATES + GRU_CNN_LSTM']=signtest.apply(lambda x: mean_absolute_percentage_error(x['Actual Value'], x['ATES + GRU_CNN_LSTM']), axis=1)

# %%
np.mean(np.abs((14.310 - 8.742965	) / 14.310)) * 100
# Out:
# 38.903109713487076

# %%
dff.head()
# Out:
#    ATES + CNN  ATES + DNN  ATES + GRU  ATES + GRU_CNN_LSTM
# 0   38.903112   24.064179   15.674221             1.693571
# 1   11.035717   22.327546   32.456022             8.217371
# 2    2.083525   28.950444   23.948809             5.888606
# 3  218.252808  235.505852  256.520692            55.349624
# 4   64.121786   14.217660    5.971230             0.541494

# %%
dff.to_csv('wilcoxon_hybrid_file.csv')

# %%
error= pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/wilcoxon_hybrid_file.csv")

# %%
error.head()
# Out:
#    Unnamed: 0  ATES + CNN  ATES + DNN  ATES + GRU  ATES + GRU_CNN_LSTM
# 0           0   38.903112   24.064179   15.674221             1.693571
# 1           1   11.035717   22.327546   32.456022             8.217371
# 2           2    2.083525   28.950444   23.948809             5.888606
# 3           3  218.252808  235.505852  256.520692            55.349624
# 4           4   64.121786   14.217660    5.971230             0.541494

# %%
stat, p,z = wilcoxon(error['ATES + GRU_CNN_LSTM'],error['ATES + GRU'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
print(p)
print(z)

# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=1.000, p=0.000
# 1.9209211049031396e-06
# -4.761570560657986
# Different distribution (reject H0)

# %%
robut= pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/TS_FORECAST_60%.csv",parse_dates=['date'],index_col='date')

#convert date field from string to datetime
#df['date'] = pd.to_datetime(df['date'])

# %%
robut.head()
# Out:
#             Unnamed: 0  Unnamed: 0.1  actual_value      arima    Prophet  \
# date
# 2015-11-10           0             0         4.386   9.286938  11.027575
# 2015-12-10           1             1        10.317  12.393542  13.712123
# 2015-10-13           2             2         7.598  13.328851  13.136254
# 2015-10-14           3             3        15.872  14.079578   7.958804
# 2015-10-15           4             4        18.938  13.242960  11.904004
#
#                Sarima        SES  Holt_Winter
# date
# 2015-11-10  13.053703  10.852424    14.113855
# 2015-12-10  12.912117  10.852424    11.606816
# 2015-10-13  12.915222  10.852424    11.510771
# 2015-10-14  12.915154  10.852424    14.062201
# 2015-10-15  12.915155  10.852424    10.028837

# %%
mean_absolute_percentage_error(robut['actual_value'],robut['SES'])
# Out:
# 62.88458247095701
