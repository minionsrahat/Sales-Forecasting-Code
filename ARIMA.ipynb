# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/data/Splited Data s-1 to s-5/new/S_1__I_105575.csv")

# %%
df.tail()
# Out:
#           id        date  store_nbr  item_nbr  unit_sales  onpromotion
# 168  7197637  2013-06-20          1    105575        15.0          NaN
# 169  7241099  2013-06-21          1    105575        12.0          NaN
# 170  7285075  2013-06-22          1    105575         8.0          NaN
# 171  7332605  2013-06-23          1    105575         4.0          NaN
# 172  7379629  2013-06-24          1    105575         7.0          NaN

# %%
df.drop(['id','store_nbr','item_nbr','onpromotion'], axis=1,inplace=True)
#df['date'] = pd.to_datetime(df['date'])
#df['date'] = df['date'].dt.year.astype('str') + '-' + df['date'].dt.month.astype('str') + '-01'
df['date'] = pd.to_datetime(df['date'])
df = df.groupby([pd.Grouper(key='date', freq='W')])['unit_sales'].sum().reset_index()

# %%
dd=df[4:8]

# %%
dd
# Out:
#         date  unit_sales
# 4 2013-02-03          43
# 5 2013-02-10          19
# 6 2013-02-17          48
# 7 2013-02-24          34

# %%
df['date'] = df['date'].dt.year.astype('str') + '-' + df['date'].dt.month.astype('str') + '-01'
df['date'] = pd.to_datetime(df['date'])

df.head()
# Out:
#         date  unit_sales
# 0 2013-01-01         168
# 1 2013-02-01         143
# 2 2013-03-01         126
# 3 2013-04-01         191
# 4 2013-05-01         167

# %%
df=pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/data/Splited Data s-1 to s-5/new/S_1__I_105575.csv")

# %%
df.drop(['id','store_nbr','item_nbr','onpromotion'], axis=1,inplace=True)
df.head(5)
# Out:
#          date  unit_sales
# 0  2013-01-02        15.0
# 1  2013-01-03         6.0
# 2  2013-01-04         8.0
# 3  2013-01-05         7.0
# 4  2013-01-06         2.0

# %%
df_sales['date'] = pd.to_datetime(df_sales['Order Date'])

# %%
df_sales.head(5)
# Out:
#    Row ID        Order ID                 Order Date Ship Date  \
# 0    7981  CA-2014-103800    Friday, 3 January, 2014  07-01-14
# 1     740  CA-2014-112326  Saturday, 4 January, 2014  08-01-14
# 2     741  CA-2014-112326  Saturday, 4 January, 2014  08-01-14
# 3     742  CA-2014-112326  Saturday, 4 January, 2014  08-01-14
# 4    1760  CA-2014-141817    Sunday, 5 January, 2014  12-01-14
#
#         Ship Mode Customer ID  Customer Name      Segment        Country  \
# 0  Standard Class    DP-13000  Darren Powers     Consumer  United States
# 1  Standard Class    PO-19195  Phillina Ober  Home Office  United States
# 2  Standard Class    PO-19195  Phillina Ober  Home Office  United States
# 3  Standard Class    PO-19195  Phillina Ober  Home Office  United States
# 4  Standard Class    MB-18085     Mick Brown     Consumer  United States
#
#            City  ...   Region       Product ID         Category Sub-Category  \
# ...

# %%
df=df_sales[['date','Sales']]

# %%
df.head(5)
# Out:
#         date  unit_sales
# 0 2013-01-01        15.0
# 1 2013-01-01         6.0
# 2 2013-01-01         8.0
# 3 2013-01-01         7.0
# 4 2013-01-01         2.0

# %%
df['date'] = pd.to_datetime(df['date'])
df['date'] = df['date'].dt.year.astype('str') + '-' + df['date'].dt.month.astype('str') + '-01'
df['date'] = pd.to_datetime(df['date'])
#groupby date and sum the sales
df= df.groupby( [pd.Grouper(key='date', freq='W')]).unit_sales.sum().reset_index()

# %%
df.head(4)
# Out:
#         date  unit_sales
# 0 2013-01-06       236.0
# 1 2013-01-13         0.0
# 2 2013-01-20         0.0
# 3 2013-01-27         0.0

# %%
lrg=['Jan', 'Feb', 'Mar', 'Apr', 'Mar', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
k=['r','b','g','r','m','y','k''w']
v=0
i=len(df.index)
lg=0
for inc in range(0,36):
        dd=df[inc:inc+12]
        inc=inc+12;
        ax = plt.subplot( 111,projection='polar')
        x=np.array(dd['Sales'])
        if v>=6:
            v=0
        ax.plot(x,c=""+k[v])
        lg=lg+1
        v=v+1
        ax.set_theta_direction(-1)
        ax.set_theta_zero_location("N")
        
        plt.thetagrids((0, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330),labels=('Jan', 'Feb', 'Mar', 'Apr', 'Mar', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'), fmt=None)
        #plt.legend(loc='upper left', frameon=False)

# %%
df.tail(12)
df.to_csv('plt.csv')

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 7, 10

# %%
dd=df[0:12]
dd1=df.tail(12)
inc=inc+12;
ax = plt.subplot(projection='polar')
bx = plt.subplot(projection='polar')
x=np.array(dd['Sales'])
y=np.array(dd1['Sales'])
ax.plot(x,c=""+k[0],label="2014")
bx.plot(y,c=""+k[1],label='2017')
ax.set_theta_direction(-1)
ax.set_theta_zero_location("N")
bx.set_theta_direction(-1)
bx.set_theta_zero_location("N")
plt.thetagrids((0, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330),labels=('Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'), fmt=None)
plt.legend(loc='upper left', frameon=False)

# %%
import plotly.graph_objects as go

fig = go.Figure(data=
    go.Scatterpolar(
        r = [0.5,1,2,2.5,3,4],
        theta = [35,70,120,155,205,240],
        mode = 'markers',
    ))

fig.update_layout(showlegend=False)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-139-b38dbf3d6844> in <module>
# ----> 1 import plotly.graph_objects as go
#       2
#       3 fig = go.Figure(data=
#       4     go.Scatterpolar(
#       5         r = [0.5,1,2,2.5,3,4],
#
# ModuleNotFoundError: No module named 'plotly.graph_objects'

# %%
import matplotlib.pyplot as plt
k=['r','b','g','r','m','y','k''w']
ax = plt.subplot( projection='polar')
x=np.array(dd['unit_sales'])
ax.plot(x,c=k[0])
ax.set_theta_direction(-1)
ax.set_theta_zero_location("N")
plt.thetagrids((0, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330),
               labels=('Jan', 'Feb', 'Mar', 'Apr', 'Mar', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'), fmt=None)
# Out:
# (<a list of 24 Line2D thetagridline objects>,
#  <a list of 12 Text thetagridlabel objects>)

# %%
k=['r','b','g','r','m','y','k''w']
ax = plt.subplot( 111,projection='polar')
x=np.array(dd['unit_sales'])
ax.plot(x,c=k[0])
ax.set_theta_direction(-1)
ax.set_theta_zero_location("N")
plt.thetagrids((0,58,115,180),labels=('1st week', '2nd week', '3rd week','4th week'), fmt=None)
# Out:
# (<a list of 8 Line2D thetagridline objects>,
#  <a list of 4 Text thetagridlabel objects>)

# %%
len(df)
# Out:
# 26

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 8,8

# %%
lrg=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
k=['r','b','g','r','m','y','k','w']
v=0
lg=0
i=24
for inc in range(0,i,4):
        dd=df[inc:inc+4]  
        ax = plt.subplot( 111,projection='polar')
        x=np.array(dd['unit_sales'])
        if lg>=11:
           lg=0
        ax.plot(x,c=""+k[v],label=lrg[lg])
        lg=lg+1
        v=v+1
        ax.set_thetamin(0)
        ax.set_thetamax(180)
        3#ax.set_theta_direction(-1)
        #ax.set_theta_zero_location("N")
        plt.thetagrids((0,58,115,180),labels=('1st week', '2nd week', '3rd week','4th week'), fmt=None)
        plt.legend(loc='upper right', frameon=False)

# %%
i=int(len(df)/4)
i
# Out:
# 6

# %%
import numpy as np
from matplotlib.pyplot import figure, show


fig = figure()

ax = fig.add_subplot(121, projection='polar')
line1, = ax.plot(dd[, np.array(cos(x))+1, xunits=radians)

ax = fig.add_subplot(122, projection='polar')
line2, = ax.plot(x, np.array(cos(x))+1, xunits=degrees)

show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-147-795738895e8d> in <module>
#       1 import numpy as np
# ----> 2 from basic_units import radians, degrees, cos
#       3 from matplotlib.pyplot import figure, show
#       4
#       5 x = [val*radians for val in np.arange(0, 15, 0.01)]
#
# ModuleNotFoundError: No module named 'basic_units'

# %%
df.drop(['id','store_nbr','item_nbr','onpromotion'], axis=1,inplace=True)

# %%
df.plot()

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=12).mean()
    rolstd = timeseries.rolling(window=12).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
test_stationarity(df)

# %%
df_diff=df.diff(periods=1)
df_diff.dropna(inplace=True)

# %%
test_stationarity(df_diff)

# %%
from sklearn.metrics import mean_squared_error 
from statsmodels.tools.eval_measures import rmse

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(df, order=(2, 1, 1))  
results_AR = model.fit(disp=-1)  
plt.plot(df,label="Orginal")
yhat = results_AR.predict(len(df), len(df), typ='levels')
plt.plot(results_AR.fittedvalues, color='red',label="Predicted")
plt.legend(loc="upper left")
plt.title("ARIMA MODEL")
plt.show()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-96-608ee16c4387> in <module>
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
# ----> 5 import xgboost as xgb
#       6 from xgboost import plot_importance, plot_tree
#       7 from sklearn.metrics import mean_squared_error, mean_absolute_error
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
train = df.iloc[0:140]
test = df.iloc[140:]

# %%
 # set one year(12 months) for testing 
  
# Fit a SARIMAX(0, 1, 1)x(2, 1, 1, 12) on the training set 
from statsmodels.tsa.statespace.sarimax import SARIMAX 
  
model = SARIMAX(train['unit_sales'],  
                order = (1, 1, 1),  
                seasonal_order =(2, 1, 1, 12)) 
  
result = model.fit() 
result.summary()

# %%
start = len(train) 
end = len(train) + len(test) - 1
  
# Predictions for one-year against the test set 
predictions = result.predict(start, end, 
                             typ = 'levels').rename("Predictions") 
  
# plot predictions and actual values 
predictions.plot(legend = True)

# %%
rmse(test["unit_sales"], predictions)

# %%
predictions.shape[0]

# %%
test.shape[0]

# %%
import os
paths_to_folders = ['C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/data/Splited Data s-1 to s-5/new']

for folder in paths_to_folders:
   for csv_file in os.listdir(folder):
     df=pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/data/Splited Data s-1 to s-5/new/"+csv_file,parse_dates=['date'],date_parser=dateparse,index_col='date')
     print(len(df.index))

# %%
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 9, 10

# %%
import os
paths_to_folders = ['C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/data/Splited Data s-1 to s-5/new']
p=0
v=0
for folder in paths_to_folders:
   for csv_file in os.listdir(folder):
        df=pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/data/Splited Data s-1 to s-5/new/"+csv_file)
        if len(df.index)>=100:
            df.drop(['id','store_nbr','item_nbr','onpromotion'], axis=1,inplace=True)
            df['date'] = pd.to_datetime(df['date'])
            df['date'] = df['date'].dt.year.astype('str') + '-' + df['date'].dt.month.astype('str') + '-01'
            df['date'] = pd.to_datetime(df['date'])
            df = df.groupby([pd.Grouper(key='date', freq='W-MON')]).unit_sales.sum().reset_index()
            k=['r','b','g','m','y','k','w']
            ax = plt.subplot( projection='polar')
            x=np.array(df['unit_sales'])
            ax.plot(x,c=k[p],label= '201'+str(v))
            p=p+1
            ax.set_theta_direction(-1)
            ax.set_theta_zero_location("N")
            plt.thetagrids((0, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330),labels=('Jan', 'Feb', 'Mar', 'Apr', 'Mar', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'), fmt=None)
            plt.legend(loc='upper left', frameon=False)
            v=v+1

# %%
dff=pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/Arima_Fore_cast_error.csv")

# %%
select_indices=list(np.where(dff["File_name"] == 'S_1__I_1055755.csv')[0])

# %%
select_indices[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-e6d17a760140> in <module>
# ----> 1 select_indices[0]
#
# IndexError: list index out of range

# %%
print(select_indices)
# Out:
# [72]

# %%
if len(select_indices)==1:
    x=dff.iloc[select_indices[0]]['RMSE_ERROR']
    print(x)

# %%
P=dff[dff['File_name'].str.contains('S_1__I_105575.csv')]

# %%
P
# Out:
#     Unnamed: 0          File_name  RMSE_ERROR        MSE       MAPE
# 72          72  S_1__I_105575.csv    5.704834  32.545132  70.798276

# %%
if  any(dff.File_name =='S_1__I_1055775.csv')==True:
    print("Hello")

# %%
pp=dff.sort_values('RMSE_ERROR',ascending=True)

# %%
modified=pp.head(100)

# %%
modified.to_csv("sorted_arima.csv")

# %%
diff=pd.read_csv("C:/Users/RAHAT/Downloads/Untitled Folder/Sales_f/sorted_arima.csv")

# %%
diff.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1           File_name  RMSE_ERROR       MSE  \
# 0         653           653   S_1__I_671699.csv    0.563262  0.317265
# 1         404           404   S_1__I_368419.csv    0.723397  0.523303
# 2         278           278   S_1__I_258395.csv    0.749940  0.562411
# 3         721           721   S_1__I_770453.csv    0.785753  0.617408
# 4         406           406   S_1__I_368624.csv    0.829066  0.687350
# 5         379           379   S_1__I_358519.csv    0.832421  0.692925
# 6          79            79  S_1__I_1057515.csv    0.834503  0.696395
# 7         470           470   S_1__I_457688.csv    0.862647  0.744159
# 8          99            99  S_1__I_1079254.csv    0.862930  0.744648
# 9         360           360   S_1__I_322095.csv    0.922497  0.851002
#
#          MAPE
# 0  120.500488
# 1   44.215560
# 2   33.229080
# 3   44.206679
# 4   62.960927
# 5   39.643459
# 6   44.282873
# 7   37.584071
# 8   45.935279
# 9   37.948484

# %%
elect_indices=list(np.where(diff["File_name"] == 'S_1__I_358519.csv')[0])

# %%
elect_indices
# Out:
# [5]

# %%
diff.iloc[elect_indices[0]]['RMSE_ERROR']
# Out:
# 0.8324214236188145
